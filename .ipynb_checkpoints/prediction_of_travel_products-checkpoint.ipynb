# %% [markdown]
# # Prediction of travel products

# %% [markdown]
# ## 1. 프로젝트 주제 : 여행 패키지 상품 신청 예측 프로젝트

# %% [markdown]
# * 해결하고자 하는 문제 : 여행 패키지상품을 고객이 신청할 지 여부를 예측하고자 한다.
# * 데이터
#     * 데이콘의 고객데이터 (train : 1955개, test : 2933개의 데이터)
#     * 선정이유 : 코로나시국 이후로 관광을 많이 못한 사람들의 여행수요가 증가하고 있다. 많은 수요자 중 어떤 고객의 특성이 여행상품을 선택할 지 예측해보고자 한다.
#     * 사용할 Target 특성은 ProdTaken(여행 패키지 신청 여부)로, binary 분류문제이다.

# %% [markdown]
# ### test값에서는 결측치 없애면 안된당..................
# ### 데이터에서 직급은 삭제할까...!!
# ### Ages를 삭제할지, Age를 삭제할지 다시 생각해보기!

# %% [markdown]
# ## 2. Import Library and Data

# %%
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt

from catboost import CatBoostClassifier
from category_encoders import OrdinalEncoder

from imblearn.over_sampling import SMOTE

from matplotlib import rcParams

from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer # 결측치를 평균으로 대체
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, plot_confusion_matrix, accuracy_score, f1_score,roc_curve, roc_auc_score

from xgboost import XGBClassifier

import seaborn as sns

# %%
# seaborn setting

rcParams['figure.figsize'] = 15,8
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.size'] = 15
colors = sns.color_palette('pastel')

# %%
train = pd.read_csv('data/train.csv')
testsheet = pd.read_csv('data/test.csv')
train.head()
# Out:
#    id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0   1  28.0  Company Invited         1             10.0  Small Business
# 1   2  34.0     Self Enquiry         3              NaN  Small Business
# 2   3  45.0  Company Invited         1              NaN        Salaried
# 3   4  29.0  Company Invited         1              7.0  Small Business
# 4   5  42.0     Self Enquiry         3              6.0        Salaried
#
#    Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0    Male                       3                4.0          Basic
# 1  Female                       2                4.0         Deluxe
# 2    Male                       2                3.0         Deluxe
# 3    Male                       3                5.0          Basic
# 4    Male                       2                3.0         Deluxe
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                    3.0       Married            3.0         0
# 1                    4.0        Single            1.0         1
# 2                    4.0       Married            2.0         0
# 3                    4.0       Married            3.0         0
# 4                    3.0      Divorced            2.0         0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                       1       0                       1.0   Executive
# 1                       5       1                       0.0     Manager
# 2                       4       1                       0.0     Manager
# 3                       4       0                       1.0   Executive
# 4                       3       1                       0.0     Manager
#
#    MonthlyIncome  ProdTaken
# 0        20384.0          0
# 1        19599.0          1
# 2            NaN          0
# 3        21274.0          1
# 4        19907.0          0

# %%
print(train.shape, testsheet.shape)
# Out:
# (1955, 20) (2933, 19)

# %% [markdown]
# ### 특성 설명(데이콘)
#
# id : 샘플 아이디
# Age : 나이
# TypeofContact : 고객의 제품 인지 방법 (회사의 홍보 or 스스로 검색)
# CityTier : 주거 중인 도시의 등급. (인구, 시설, 생활 수준 기준) (1등급 > 2등급 > 3등급)
# DurationOfPitch : 영업 사원이 고객에게 제공하는 프레젠테이션 기간
# Occupation : 직업
# Gender : 성별
# NumberOfPersonVisiting : 고객과 함께 여행을 계획 중인 총 인원
# NumberOfFollowups : 영업 사원의 프레젠테이션 후 이루어진 후속 조치 수
# ProductPitched : 영업 사원이 제시한 상품
# PreferredPropertyStar : 선호 호텔 숙박업소 등급
# MaritalStatus : 결혼여부
# NumberOfTrips : 평균 연간 여행 횟수
# Passport : 여권 보유 여부 (0: 없음, 1: 있음)
# PitchSatisfactionScore : 영업 사원의 프레젠테이션 만족도
# OwnCar : 자동차 보유 여부 (0: 없음, 1: 있음)
# NumberOfChildrenVisiting : 함께 여행을 계획 중인 5세 미만의 어린이 수
# Designation : (직업의) 직급
# MonthlyIncome : 월 급여
# ProdTaken : 여행 패키지 신청 여부 (0: 신청 안 함, 1: 신청함)

# %% [markdown]
# ## 3. 가설, 기준모델(Baseline Model), 평가지표설명

# %% [markdown]
# * 가설(탐색적데이터분석)
#     * 가설1 : 결혼 후, 여행을 계획중인 아이들이 있으면 가족패키지에 대한 수요가 있어 패키지신청확률이 높을 것이다.
#     * 가설2 : 영업 사원의 프레젠테이션 만족도는 가족패키지에 대한 수요가 높을 것이다.
#     * 가설3 : 여행 패키지를 신청한 사람들의 소득은 2022년 1/4분기 월평균소득인 4,825,000원보다 높을 것이다.
#              (개인별인지 가구별인지 물어보는중임)
#     통계청 자료참조.(https://kostat.go.kr/portal/korea/kor_nw/1/1/index.board?bmode=read&aSeq=418357)
#
# * 기준모델 및 평가지표설명
#     * Baseline Model은 초기 최빈값인 0.20에서 ---으로 변경

# %% [markdown]
# ## 4. Data Preprocessing and EDA

# %% [markdown]
# ### 1) EDA
#     * Gender 컬럼의 'Fe Male'->'Female'로 수정
#     * 결측치제거
#     * unique 컬럼 제거(id)

# %%
train.info() # 1955*20
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955 entries, 0 to 1954
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1955 non-null   int64
#  1   Age                       1861 non-null   float64
#  2   TypeofContact             1945 non-null   object
#  3   CityTier                  1955 non-null   int64
#  4   DurationOfPitch           1853 non-null   float64
#  5   Occupation                1955 non-null   object
#  6   Gender                    1955 non-null   object
#  7   NumberOfPersonVisiting    1955 non-null   int64
#  8   NumberOfFollowups         1942 non-null   float64
#  9   ProductPitched            1955 non-null   object
#  10  PreferredPropertyStar     1945 non-null   float64
#  11  MaritalStatus             1955 non-null   object
#  12  NumberOfTrips             1898 non-null   float64
#  13  Passport                  1955 non-null   int64
#  14  PitchSatisfactionScore    1955 non-null   int64
#  15  OwnCar                    1955 non-null   int64
#  16  NumberOfChildrenVisiting  1928 non-null   float64
#  17  Designation               1955 non-null   object
#  18  MonthlyIncome             1855 non-null   float64
#  19  ProdTaken                 1955 non-null   int64
# dtypes: float64(7), int64(7), object(6)
# memory usage: 305.6+ KB

# %%
testsheet.info() # 2933*19
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2933 entries, 0 to 2932
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        2933 non-null   int64
#  1   Age                       2801 non-null   float64
#  2   TypeofContact             2918 non-null   object
#  3   CityTier                  2933 non-null   int64
#  4   DurationOfPitch           2784 non-null   float64
#  5   Occupation                2933 non-null   object
#  6   Gender                    2933 non-null   object
#  7   NumberOfPersonVisiting    2933 non-null   int64
#  8   NumberOfFollowups         2901 non-null   float64
#  9   ProductPitched            2933 non-null   object
#  10  PreferredPropertyStar     2917 non-null   float64
#  11  MaritalStatus             2933 non-null   object
#  12  NumberOfTrips             2850 non-null   float64
#  13  Passport                  2933 non-null   int64
#  14  PitchSatisfactionScore    2933 non-null   int64
#  15  OwnCar                    2933 non-null   int64
#  16  NumberOfChildrenVisiting  2894 non-null   float64
#  17  Designation               2933 non-null   object
#  18  MonthlyIncome             2800 non-null   float64
# dtypes: float64(7), int64(6), object(6)
# memory usage: 435.5+ KB

# %%
# 결측치확인

train.isnull().sum()
# Out:
# id                            0
# Age                          94
# TypeofContact                10
# CityTier                      0
# DurationOfPitch             102
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            13
# ProductPitched                0
# PreferredPropertyStar        10
# MaritalStatus                 0
# NumberOfTrips                57
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     27
# Designation                   0
# MonthlyIncome               100
# ProdTaken                     0
# dtype: int64

# %%
'''def preprocessing(df):
    
    # Gender 특성 데이터정리
    df['Gender'] = df['Gender'].str.replace('Fe Male', 'Female')
    
    # 결측치는 SimpleImputer의 최빈값으로 정리해보기로함. 'Age', 'DurationOfPitch', 'NumberOfFollowups', 'NumberOfChildrenVisiting', 'MonthlyIncome'])
    
    # TypeofContact 데이터는 범주형이라 판단하여 결측치 제거(구분이 3개)
    df['TypeofContact'] = df['TypeofContact'].dropna()
    
    # PreferredPropertyStar 데이터는 범주형이라 판단하여 결측치 제거(구분이 3개)
    df['PreferredPropertyStar'] = df['PreferredPropertyStar'].dropna()
    
    # NumberOfChildrenVisiting 데이터는 범주형이라 판단하여 결측치 제거(구분이 4개)
    df['NumberOfChildrenVisiting'] = df['NumberOfChildrenVisiting'].dropna()
    
    # NumberOfTrips
    #df['NumberOfTrips'] = df['NumberOfTrips'] # 얘는 평균이 아니라 median으로 하는게 좋을 듯 (이상치있음)
    return df

'''
# Out:
# "def preprocessing(df):\n    \n    # Gender 특성 데이터정리\n    df['Gender'] = df['Gender'].str.replace('Fe Male', 'Female')\n    \n    # 결측치는 SimpleImputer의 최빈값으로 정리해보기로함. 'Age', 'DurationOfPitch', 'NumberOfFollowups', 'NumberOfChildrenVisiting', 'MonthlyIncome'])\n    \n    # TypeofContact 데이터는 범주형이라 판단하여 결측치 제거(구분이 3개)\n    df['TypeofContact'] = df['TypeofContact'].dropna()\n    \n    # PreferredPropertyStar 데이터는 범주형이라 판단하여 결측치 제거(구분이 3개)\n    df['PreferredPropertyStar'] = df['PreferredPropertyStar'].dropna()\n    \n    # NumberOfChildrenVisiting 데이터는 범주형이라 판단하여 결측치 제거(구분이 4개)\n    df['NumberOfChildrenVisiting'] = df['NumberOfChildrenVisiting'].dropna()\n    \n    # NumberOfTrips\n    #df['NumberOfTrips'] = df['NumberOfTrips'] # 얘는 평균이 아니라 median으로 하는게 좋을 듯 (이상치있음)\n    return df\n\n"

# %%
'''data_ = preprocessing(train)
data_.head()'''
# Out:
# 'data_ = preprocessing(train)\ndata_.head()'

# %%
def data_preprocessing(df):
    
    # Gender 특성 데이터정리
    df['Gender'] = df['Gender'].str.replace('Fe Male', 'Female')
    
    df = df.dropna()
    
    # 나이를 기준으로 나이대별 컬럼생성
    # df['Ages'] = (df['Age']//10*10).astype(int)
    # Age컬럼 삭제하기
    
    # 새로운 특성 만들고 난 후 불필요한 컬럼 삭제
    df = df.drop(['id'],axis=1)
    
    return df

# %%
data = data_preprocessing(train)
data.head()
# Out:
#     Age    TypeofContact  CityTier  DurationOfPitch      Occupation Gender  \
# 0  28.0  Company Invited         1             10.0  Small Business   Male
# 3  29.0  Company Invited         1              7.0  Small Business   Male
# 4  42.0     Self Enquiry         3              6.0        Salaried   Male
# 5  32.0     Self Enquiry         1             29.0  Small Business   Male
# 6  43.0  Company Invited         3              8.0        Salaried   Male
#
#    NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0                       3                4.0          Basic
# 3                       3                5.0          Basic
# 4                       2                3.0         Deluxe
# 5                       4                4.0         Deluxe
# 6                       3                3.0         Deluxe
#
#    PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                    3.0       Married            3.0         0
# 3                    4.0       Married            3.0         0
# 4                    3.0      Divorced            2.0         0
# 5                    3.0      Divorced            3.0         1
# 6                    3.0       Married            2.0         0
#
#    PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                       1       0                       1.0   Executive
# 3                       4       0                       1.0   Executive
# 4                       3       1                       0.0     Manager
# 5                       5       1                       1.0     Manager
# 6                       3       1                       2.0     Manager
#
#    MonthlyIncome  ProdTaken
# 0        20384.0          0
# 3        21274.0          1
# 4        19907.0          0
# 5        24857.0          1
# 6        20675.0          0

# %%
# 테스트데이터도 추후 전처리 해줘야함!!!! 모델링하는거 봐서 더 잘 먹는걸로 전처리하기!

# %%
# 컬럼별 데이터내용 확인
data.describe()
# Out:
#                Age     CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# count  1649.000000  1649.000000      1649.000000             1649.000000
# mean     37.021225     1.646452        15.627653                2.970285
# std       9.049227     0.912721         8.149520                0.704331
# min      18.000000     1.000000         5.000000                1.000000
# 25%      31.000000     1.000000         9.000000                2.000000
# 50%      36.000000     1.000000        14.000000                3.000000
# 75%      43.000000     3.000000        21.000000                3.000000
# max      61.000000     3.000000        36.000000                5.000000
#
#        NumberOfFollowups  PreferredPropertyStar  NumberOfTrips     Passport  \
# count        1649.000000            1649.000000    1649.000000  1649.000000
# mean            3.752577               3.565191       3.316555     0.297150
# std             1.017758               0.787972       1.818987     0.457142
# min             1.000000               3.000000       1.000000     0.000000
# 25%             3.000000               3.000000       2.000000     0.000000
# 50%             4.000000               3.000000       3.000000     0.000000
# 75%             4.000000               4.000000       4.000000     1.000000
# max             6.000000               5.000000      19.000000     1.000000
#
#        PitchSatisfactionScore       OwnCar  NumberOfChildrenVisiting  \
# count             1649.000000  1649.000000               1649.000000
# mean                 3.048514     0.610673                  1.257732
# std                  1.372873     0.487746                  0.853130
# min                  1.000000     0.000000                  0.000000
# 25%                  2.000000     0.000000                  1.000000
# 50%                  3.000000     1.000000                  1.000000
# 75%                  4.000000     1.000000                  2.000000
# max                  5.000000     1.000000                  3.000000
#
#        MonthlyIncome    ProdTaken
# count    1649.000000  1649.000000
# mean    23141.996968     0.203760
# std      4649.463051     0.402915
# min      1000.000000     0.000000
# 25%     20764.000000     0.000000
# 50%     22359.000000     0.000000
# 75%     25266.000000     0.000000
# max     98678.000000     1.000000

# %%
# 컬럼별 데이터 내용 확인
for i in data.columns:
    print(data[i].value_counts())
# Out:
# 35.0    90
# 33.0    84
# 37.0    81
# 32.0    79
# 36.0    74
# 38.0    73
# 30.0    68
# 34.0    68
# 41.0    66
# 31.0    64
# 29.0    63
# 39.0    58
# 28.0    55
# 40.0    51
# 27.0    46
# 45.0    43
# 43.0    43
# 42.0    39
# 26.0    37
# 46.0    37
# 44.0    34
# 49.0    28
# 47.0    26
# 25.0    26
# 51.0    25
# 53.0    25
# 50.0    23
# 23.0    23
# 54.0    22
# 24.0    21
# 48.0    20
# 22.0    19
# 55.0    18
# 21.0    17
# 52.0    17
# 19.0    14
# 59.0    13
# 20.0    12
# 58.0    11
# 60.0    11
# 56.0     9
# 57.0     8
# 18.0     5
# 61.0     3
# Name: Age, dtype: int64
# Self Enquiry       1164
# Company Invited     485
# Name: TypeofContact, dtype: int64
# 1    1081
# 3     498
# 2      70
# Name: CityTier, dtype: int64
# 9.0     171
# 7.0     114
# 8.0     105
# 6.0     102
# 16.0    100
# 15.0     96
# 14.0     94
# 10.0     88
# 13.0     80
# 12.0     78
# 11.0     71
# 17.0     66
# 23.0     39
# 30.0     36
# 31.0     33
# 25.0     31
# 27.0     31
# 20.0     29
# 22.0     29
# 32.0     28
# 24.0     25
# 35.0     24
# 26.0     23
# 28.0     23
# 21.0     22
# 29.0     22
# 18.0     22
# 19.0     18
# 34.0     17
# 33.0     16
# 36.0     14
# 5.0       2
# Name: DurationOfPitch, dtype: int64
# Salaried          808
# Small Business    693
# Large Business    147
# Free Lancer         1
# Name: Occupation, dtype: int64
# Male      1024
# Female     625
# Name: Gender, dtype: int64
# 3    851
# 2    415
# 4    376
# 1      6
# 5      1
# Name: NumberOfPersonVisiting, dtype: int64
# 4.0    729
# 3.0    436
# 5.0    293
# 2.0     83
# 1.0     63
# 6.0     45
# Name: NumberOfFollowups, dtype: int64
# Basic           657
# Deluxe          564
# Standard        298
# Super Deluxe     94
# King             36
# Name: ProductPitched, dtype: int64
# 3.0    1026
# 4.0     314
# 5.0     309
# Name: PreferredPropertyStar, dtype: int64
# Married      804
# Divorced     307
# Unmarried    282
# Single       256
# Name: MaritalStatus, dtype: int64
# 2.0     515
# 3.0     390
# 1.0     174
# 4.0     166
# 5.0     163
# 6.0     120
# 7.0      83
# 8.0      37
# 19.0      1
# Name: NumberOfTrips, dtype: int64
# 0    1159
# 1     490
# Name: Passport, dtype: int64
# 3    483
# 1    333
# 4    317
# 5    315
# 2    201
# Name: PitchSatisfactionScore, dtype: int64
# 1    1007
# 0     642
# Name: OwnCar, dtype: int64
# 1.0    709
# 2.0    498
# 0.0    319
# 3.0    123
# Name: NumberOfChildrenVisiting, dtype: int64
# Executive         657
# Manager           564
# Senior Manager    298
# AVP                94
# VP                 36
# Name: Designation, dtype: int64
# 21162.0    4
# 25609.0    4
# 24840.0    4
# 21398.0    4
# 21288.0    4
#           ..
# 25245.0    1
# 26014.0    1
# 21949.0    1
# 24453.0    1
# 17853.0    1
# Name: MonthlyIncome, Length: 1311, dtype: int64
# 0    1313
# 1     336
# Name: ProdTaken, dtype: int64

# %%
# data_.describe()

# %% [markdown]
# ## 4. 시각화

# %%
# 특성별 상관관계 히트맵으로 표현.
sns.heatmap(data=data.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='Blues');

# %% [markdown]
# * 특성간 상관관계가 높을수록 진한색을 띄는데, 데이터를 확인시, 특성간 뚜렷한 상관관계가 보이지 않음을 확인하였다.
#
#
# * 타겟인 ProdTaken와 상관관계가 가장 높은 것은 여권소지유무로 0.32가 가장 높은 값이다.
# * 함께 여행을 계획 중인 5세 미만의 어린이 수 고객과 함께 여행을 계획 중인 총 인원은 0.6의 상관관계로 상관관계수치 중 가장 높은 값을 보인다.
#
#
# * 타겟의 상관관계가 음수로 나타난 경우
#     * 나이와 타겟의 상관관계 : 이는 고령일수록 패키지여행신청을 하지 않음을 보여준다.
#     * 차량과 타겟의 상관관계 : 차가 없는 경우가 패키지여행을 더 고려하는 것을 보여준다.
#     * 월별소득과 타겟의 상관관계 : 소득이 적을 때 패키지여행을 더 고려하는 것을 보여준다.

# %%
# 타겟 구성비율확인
print(data['ProdTaken'].value_counts())

print(data['ProdTaken'].value_counts(normalize=True))
# Out:
# 0    1313
# 1     336
# Name: ProdTaken, dtype: int64
# 0    0.79624
# 1    0.20376
# Name: ProdTaken, dtype: float64

# %%
# 타겟의 imbalance 확인
# %matplotlib inline

sns.countplot(data['ProdTaken']);
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# ProdTaken이 1로 나온 특성별 분포확인(여행패키지 신청한 경우)

dataa = data[data['ProdTaken']==1]
dataa.shape
# Out:
# (336, 19)

# %%
for i in dataa.columns:
    sns.displot(dataa[i],kde=True) # kde : 커널밀도추정. 커널함수와 데이터를 바탕으로 연속성있는 확률밀도함수를 추정하는것.
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
data['Occupation'].value_counts()
# Out:
# Salaried          808
# Small Business    693
# Large Business    147
# Free Lancer         1
# Name: Occupation, dtype: int64

# %%
# could not convert string to float: 'Company Invited' 이런 에러가 떠서 했었음.
# data['Occupation'] = data['Occupation'].str.strip()

# %%
for i in dataa.columns:
    sns.displot(dataa[i],kde=True) # kde : 커널밀도추정. 커널함수와 데이터를 바탕으로 연속성있는 확률밀도함수를 추정하는것.
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
def plot_counts(dataframe):
    dataframe['ProdTaken'].value_counts()
    sns.countplot(data=dataframe, x='ProdTaken')

# %%
data.columns
# Out:
# Index(['Age', 'TypeofContact', 'CityTier', 'DurationOfPitch', 'Occupation',
#        'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'ProdTaken'],
#       dtype='object')

# %%
sns.countplot(data=data,x='ProdTaken')

# %%
# 패키지 선택한 성 비율
yes = data[data.ProdTaken==1]

# 패키지 미선택한 성비율 
no = data[data.ProdTaken==0]

# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1


pie_data=yes['Gender'].value_counts()
labels=yes['Gender'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)

ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 성 비율',fontsize=30)


pie_data=no['Gender'].value_counts()
labels=no['Gender'].value_counts().index
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 성 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 성 비율')

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['Occupation'].value_counts()
labels=yes['Occupation'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)

ax1.pie(pie_data,labels = labels,colors = colors,explode=explode, autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 직업군 비율',fontsize=30)


pie_data=no['Occupation'].value_counts()
labels=no['Occupation'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)

ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 직업군 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 직업군 비율')

# %% [markdown]
# ### 가설1 : 결혼 후, 여행을 계획중인 아이들이 있으면 가족패키지에 대한 수요가 있어 패키지신청확률이 높을 것이다.

# %%
# 결혼한 경우의 데이터를 추린다.
condition=data[(data.MaritalStatus=='Married')] #| (data.MaritalStatus=='Divorced')]
condition['MaritalStatus'].value_counts()
# Out:
# Married    804
# Name: MaritalStatus, dtype: int64

# %%
# 함께 여행을 계획 중인 5세 미만의 어린이 수가 있는 경우의 조건을 추가한다.
aaaaaaa = condition[condition['NumberOfChildrenVisiting']>0]

# 타겟의 imbalance 확인
# %matplotlib inline

sns.countplot(aaaaaaa['ProdTaken']);
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# 타겟 구성비율확인
print(aaaaaaa['ProdTaken'].value_counts())

print(aaaaaaa['ProdTaken'].value_counts(normalize=True))
# Out:
# 0    552
# 1    102
# Name: ProdTaken, dtype: int64
# 0    0.844037
# 1    0.155963
# Name: ProdTaken, dtype: float64

# %% [markdown]
# 해당가설은 최빈값보다 줄어드는 결과를 가져왔고, 이는 결혼 후 여행에 계획중인 아이들은 패키지여행선택과는 무관함을 보여준다.
# (결혼을 하고 애가 있는 경우(이혼한 경우도) 진행했으나 married와 비슷한 수치를 보였다.)

# %% [markdown]
# ### 가설2 : 영업 사원의 프레젠테이션 만족도는 가족패키지에 대한 수요가 높을 것이다.

# %%
# 가설2에 따른 영업사원의 프레젠테이션만족도는 가족패키지에 대한 수요를 높일 것이다로 했을 시, 최빈값보다 0.03이 오른 것을 확인할 수 있다.

condition2 = data[data['PitchSatisfactionScore']>=3]
condition2[condition2['NumberOfChildrenVisiting']>0]['ProdTaken'].value_counts(normalize=True)
# Out:
# 0    0.768632
# 1    0.231368
# Name: ProdTaken, dtype: float64

# %%
# 패키지여행상품선택여부와 소득의 관계표현
sns.boxplot(data=data, x="ProdTaken", y="MonthlyIncome")

# %%
yes
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 3     29.0  Company Invited         1              7.0  Small Business
# 5     32.0     Self Enquiry         1             29.0  Small Business
# 7     32.0     Self Enquiry         3             20.0  Small Business
# 9     34.0     Self Enquiry         1              7.0        Salaried
# 10    35.0  Company Invited         1             14.0        Salaried
# ...    ...              ...       ...              ...             ...
# 1930  55.0     Self Enquiry         3             19.0  Small Business
# 1937  29.0  Company Invited         3             20.0  Large Business
# 1942  38.0  Company Invited         1             15.0        Salaried
# 1943  28.0     Self Enquiry         1             14.0        Salaried
# 1954  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 3       Male                       3                5.0          Basic
# 5       Male                       4                4.0         Deluxe
# 7       Male                       4                5.0         Deluxe
# 9       Male                       4                4.0          Basic
# 10      Male                       4                6.0         Deluxe
# ...      ...                     ...                ...            ...
# 1930    Male                       2                1.0   Super Deluxe
# 1937  Female                       3                4.0         Deluxe
# 1942    Male                       3                3.0         Deluxe
# 1943  Female                       2                4.0          Basic
# 1954    Male                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 3                       4.0       Married            3.0         0
# 5                       3.0      Divorced            3.0         1
# 7                       5.0       Married            7.0         1
# 9                       3.0     Unmarried            3.0         1
# 10                      3.0     Unmarried            3.0         1
# ...                     ...           ...            ...       ...
# 1930                    3.0        Single            7.0         1
# 1937                    4.0     Unmarried            7.0         0
# 1942                    5.0       Married            5.0         0
# 1943                    4.0        Single            2.0         0
# 1954                    3.0      Divorced            1.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 3                          4       0                       1.0   Executive
# 5                          5       1                       1.0     Manager
# 7                          1       1                       1.0     Manager
# 9                          3       1                       1.0   Executive
# 10                         5       1                       1.0     Manager
# ...                      ...     ...                       ...         ...
# 1930                       3       1                       1.0         AVP
# 1937                       3       1                       1.0     Manager
# 1942                       3       0                       2.0     Manager
# 1943                       4       0                       1.0   Executive
# 1954                       3       0                       0.0   Executive
#
#       MonthlyIncome  ProdTaken
# 3           21274.0          1
# 5           24857.0          1
# 7           20980.0          1
# 9           21364.0          1
# 10          24752.0          1
# ...             ...        ...
# 1930        28695.0          1
# 1937        22545.0          1
# 1942        21893.0          1
# 1943        17154.0          1
# 1954        17853.0          1
#
# [336 rows x 19 columns]

# %%
data.describe()
# Out:
#                Age     CityTier  DurationOfPitch  NumberOfPersonVisiting  \
# count  1649.000000  1649.000000      1649.000000             1649.000000
# mean     37.021225     1.646452        15.627653                2.970285
# std       9.049227     0.912721         8.149520                0.704331
# min      18.000000     1.000000         5.000000                1.000000
# 25%      31.000000     1.000000         9.000000                2.000000
# 50%      36.000000     1.000000        14.000000                3.000000
# 75%      43.000000     3.000000        21.000000                3.000000
# max      61.000000     3.000000        36.000000                5.000000
#
#        NumberOfFollowups  PreferredPropertyStar  NumberOfTrips     Passport  \
# count        1649.000000            1649.000000    1649.000000  1649.000000
# mean            3.752577               3.565191       3.316555     0.297150
# std             1.017758               0.787972       1.818987     0.457142
# min             1.000000               3.000000       1.000000     0.000000
# 25%             3.000000               3.000000       2.000000     0.000000
# 50%             4.000000               3.000000       3.000000     0.000000
# 75%             4.000000               4.000000       4.000000     1.000000
# max             6.000000               5.000000      19.000000     1.000000
#
#        PitchSatisfactionScore       OwnCar  NumberOfChildrenVisiting  \
# count             1649.000000  1649.000000               1649.000000
# mean                 3.048514     0.610673                  1.257732
# std                  1.372873     0.487746                  0.853130
# min                  1.000000     0.000000                  0.000000
# 25%                  2.000000     0.000000                  1.000000
# 50%                  3.000000     1.000000                  1.000000
# 75%                  4.000000     1.000000                  2.000000
# max                  5.000000     1.000000                  3.000000
#
#        MonthlyIncome    ProdTaken
# count    1649.000000  1649.000000
# mean    23141.996968     0.203760
# std      4649.463051     0.402915
# min      1000.000000     0.000000
# 25%     20764.000000     0.000000
# 50%     22359.000000     0.000000
# 75%     25266.000000     0.000000
# max     98678.000000     1.000000

# %%
data[data['Occupation']=='Salaried']
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch Occupation  Gender  \
# 4     42.0     Self Enquiry         3              6.0   Salaried    Male
# 6     43.0  Company Invited         3              8.0   Salaried    Male
# 9     34.0     Self Enquiry         1              7.0   Salaried    Male
# 10    35.0  Company Invited         1             14.0   Salaried    Male
# 18    36.0     Self Enquiry         1              8.0   Salaried  Female
# ...    ...              ...       ...              ...        ...     ...
# 1943  28.0     Self Enquiry         1             14.0   Salaried  Female
# 1945  41.0     Self Enquiry         3             12.0   Salaried  Female
# 1949  53.0     Self Enquiry         1             15.0   Salaried  Female
# 1951  41.0     Self Enquiry         3              8.0   Salaried  Female
# 1954  22.0  Company Invited         1              9.0   Salaried    Male
#
#       NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 4                          2                3.0         Deluxe
# 6                          3                3.0         Deluxe
# 9                          4                4.0          Basic
# 10                         4                6.0         Deluxe
# 18                         3                3.0          Basic
# ...                      ...                ...            ...
# 1943                       2                4.0          Basic
# 1945                       3                3.0       Standard
# 1949                       3                4.0          Basic
# 1951                       3                3.0   Super Deluxe
# 1954                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 4                       3.0      Divorced            2.0         0
# 6                       3.0       Married            2.0         0
# 9                       3.0     Unmarried            3.0         1
# 10                      3.0     Unmarried            3.0         1
# 18                      3.0       Married            5.0         0
# ...                     ...           ...            ...       ...
# 1943                    4.0        Single            2.0         0
# 1945                    3.0        Single            4.0         1
# 1949                    5.0      Divorced            2.0         0
# 1951                    5.0      Divorced            1.0         0
# 1954                    3.0      Divorced            1.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting  \
# 4                          3       1                       0.0
# 6                          3       1                       2.0
# 9                          3       1                       1.0
# 10                         5       1                       1.0
# 18                         5       1                       0.0
# ...                      ...     ...                       ...
# 1943                       4       0                       1.0
# 1945                       1       0                       0.0
# 1949                       1       1                       2.0
# 1951                       5       1                       1.0
# 1954                       3       0                       0.0
#
#          Designation  MonthlyIncome  ProdTaken
# 4            Manager        19907.0          0
# 6            Manager        20675.0          0
# 9          Executive        21364.0          1
# 10           Manager        24752.0          1
# 18         Executive        17543.0          0
# ...              ...            ...        ...
# 1943       Executive        17154.0          1
# 1945  Senior Manager        28591.0          0
# 1949       Executive        21628.0          0
# 1951             AVP        31595.0          0
# 1954       Executive        17853.0          1
#
# [808 rows x 19 columns]

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['TypeofContact'].value_counts()
labels=yes['TypeofContact'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax1.pie(pie_data,labels = labels,colors = colors,explode=explode, autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 고객의 제품인지방법 비율',fontsize=30)


pie_data=no['TypeofContact'].value_counts()
labels=no['TypeofContact'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)

ax2.pie(pie_data,labels = labels,colors = colors,explode=explode, autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 고객의 제품인지방법 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 고객의 제품인지방법 비율')

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['Occupation'].value_counts()
labels=yes['Occupation'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 직업군 비율',fontsize=30)


pie_data=no['Occupation'].value_counts()
labels=no['Occupation'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 직업군 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 직업군 비율')

# %%
# 프리랜서는 한 명인데, 직함은 Executive로 해 둔 것으로 보아 사외이사로 간주하자.
data[data['Occupation']=='Free Lancer']
# Out:
#       Age TypeofContact  CityTier  DurationOfPitch   Occupation Gender  \
# 485  37.0  Self Enquiry         1              8.0  Free Lancer   Male
#
#      NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 485                       3                4.0          Basic
#
#      PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 485                    3.0        Single            7.0         1
#
#      PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 485                       3       0                       0.0   Executive
#
#      MonthlyIncome  ProdTaken
# 485        17090.0          1

# %%
# 패키지 선택한 성 비율
yes = data[data.ProdTaken==1]

# 패키지 미선택한 성비율 
no = data[data.ProdTaken==0]

# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['Gender'].value_counts()
labels=yes['Gender'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    

ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 성 비율',fontsize=30)


pie_data=no['Gender'].value_counts()
labels=no['Gender'].value_counts().index
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 성 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 성 비율')

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['ProductPitched'].value_counts()
labels=yes['ProductPitched'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)

ax1.pie(pie_data,labels = labels,colors = colors,explode=explode, autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 영업사원상품제시 비율',fontsize=30)


pie_data=no['ProductPitched'].value_counts()
labels=no['ProductPitched'].value_counts().index
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 영업사원상품제시 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 영업사원상품제시 비율')

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['MaritalStatus'].value_counts()
labels=yes['MaritalStatus'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 결혼여부 비율',fontsize=30)


pie_data=no['MaritalStatus'].value_counts()
labels=no['MaritalStatus'].value_counts().index
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 결혼여부 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 결혼여부 비율')

# %%
# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['Designation'].value_counts()
labels=yes['Designation'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 직급 비율',fontsize=30)


pie_data=no['Designation'].value_counts()
labels=no['Designation'].value_counts().index
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 직급 비율',fontsize=30)
# Out:
# Text(0.5, 1.0, '패키지 미선택한 직급 비율')

# %% [markdown]
# 직함에 매니저라고 적어도 직업에 작은 사업, 큰 사업으로 기재된 경우가 많아, 직함은 큰 의미가 없는 것으로 파악하기로 한다.
# (기업의 규모마다 매니저의 역할/역량이 다른 경우도 많으니 큰 의미를 두지 않기로 하며, 매니저 이상의 고객군으로 파악하기로 한다.)

# %%
# 매니저 직함의 직업 종류 분포
aa = data[data['Designation']=='Manager']
aa['Occupation'].value_counts()
# Out:
# Salaried          265
# Small Business    256
# Large Business     43
# Name: Occupation, dtype: int64

# %%
# 경영진 직함의 직업 종류 분포
bb = data[data['Designation']=='Executive']
bb['Occupation'].value_counts()
# Out:
# Salaried          344
# Small Business    248
# Large Business     64
# Free Lancer         1
# Name: Occupation, dtype: int64

# %%
'''# 한번에 piechart 2개 보여주기
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies
# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1

pie_data=yes['Ages'].value_counts()
labels=yes['Ages'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie
ax1.set_title('패키지 선택한 연령대 비율',fontsize=30)


pie_data=no['Ages'].value_counts()
labels=no['Ages'].value_counts().index

explode = []
for i in range(len(labels)):
    explode.append(0.01)
    
ax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie
ax2.set_title('패키지 미선택한 연령대 비율',fontsize=30)
'''
# Out:
# "# 한번에 piechart 2개 보여주기\nfig, (ax1,ax2) = plt.subplots(1,2,figsize=(20,20)) #ax1,ax2 refer to your two pies\n# 1,2 denotes 1 row, 2 columns - if you want to stack vertically, it would be 2,1\n\npie_data=yes['Ages'].value_counts()\nlabels=yes['Ages'].value_counts().index\n\nexplode = []\nfor i in range(len(labels)):\n    explode.append(0.01)\n    \nax1.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot first pie\nax1.set_title('패키지 선택한 연령대 비율',fontsize=30)\n\n\npie_data=no['Ages'].value_counts()\nlabels=no['Ages'].value_counts().index\n\nexplode = []\nfor i in range(len(labels)):\n    explode.append(0.01)\n    \nax2.pie(pie_data,labels = labels,colors = colors,explode=explode,autopct = '%1.1f%%', textprops={'fontsize': 15}) #plot second pie\nax2.set_title('패키지 미선택한 연령대 비율',fontsize=30)\n"

# %%
# 타겟의 imbalance 확인
# %matplotlib inline

sns.countplot(data['Age']);
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0     28.0  Company Invited         1             10.0  Small Business
# 3     29.0  Company Invited         1              7.0  Small Business
# 4     42.0     Self Enquiry         3              6.0        Salaried
# 5     32.0     Self Enquiry         1             29.0  Small Business
# 6     43.0  Company Invited         3              8.0        Salaried
# ...    ...              ...       ...              ...             ...
# 1950  28.0     Self Enquiry         1             10.0  Small Business
# 1951  41.0     Self Enquiry         3              8.0        Salaried
# 1952  38.0  Company Invited         3             28.0  Small Business
# 1953  28.0     Self Enquiry         3             30.0  Small Business
# 1954  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0       Male                       3                4.0          Basic
# 3       Male                       3                5.0          Basic
# 4       Male                       2                3.0         Deluxe
# 5       Male                       4                4.0         Deluxe
# 6       Male                       3                3.0         Deluxe
# ...      ...                     ...                ...            ...
# 1950    Male                       3                5.0          Basic
# 1951  Female                       3                3.0   Super Deluxe
# 1952  Female                       3                4.0          Basic
# 1953  Female                       3                5.0         Deluxe
# 1954    Male                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0       Married            3.0         0
# 3                       4.0       Married            3.0         0
# 4                       3.0      Divorced            2.0         0
# 5                       3.0      Divorced            3.0         1
# 6                       3.0       Married            2.0         0
# ...                     ...           ...            ...       ...
# 1950                    3.0        Single            2.0         0
# 1951                    5.0      Divorced            1.0         0
# 1952                    3.0      Divorced            7.0         0
# 1953                    3.0       Married            3.0         0
# 1954                    3.0      Divorced            1.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                          1       0                       1.0   Executive
# 3                          4       0                       1.0   Executive
# 4                          3       1                       0.0     Manager
# 5                          5       1                       1.0     Manager
# 6                          3       1                       2.0     Manager
# ...                      ...     ...                       ...         ...
# 1950                       1       1                       2.0   Executive
# 1951                       5       1                       1.0         AVP
# 1952                       2       1                       2.0   Executive
# 1953                       1       1                       2.0     Manager
# 1954                       3       0                       0.0   Executive
#
#       MonthlyIncome  ProdTaken
# 0           20384.0          0
# 3           21274.0          1
# 4           19907.0          0
# 5           24857.0          1
# 6           20675.0          0
# ...             ...        ...
# 1950        20723.0          0
# 1951        31595.0          0
# 1952        21651.0          0
# 1953        22218.0          0
# 1954        17853.0          1
#
# [1649 rows x 19 columns]

# %% [markdown]
# ## 5. Modeling

# %% [markdown]
# ### 모델의 유용성과 한계
#
# * 목적 : 주어진 특성을 분석하여 패키지 여행을 신청할 지, 말 지 예측
# * 유용성 : 잠재고객을 파악하여 영업/광고방향 설정 가능
# * 한계 :

# %%
# 훈련/검증셋 나누기

train, test = train_test_split(data, test_size=0.2, random_state=2)
train, val = train_test_split(train, test_size=0.2, random_state=2)

target = 'ProdTaken'
features = data.columns.drop([target])

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]

train.shape, val.shape, test.shape
# Out:
# ((1055, 19), (264, 19), (330, 19))

# %%
ttt = pd.read_csv('data/train.csv')
ttt.shape
# Out:
# (1955, 20)

# %%
# 훈련/검증셋 나누기

train2, test2 = train_test_split(ttt, test_size=0.2, random_state=2)
train2, val2 = train_test_split(train2, test_size=0.2, random_state=2)


target = 'ProdTaken'
features = ttt.columns.drop([target])

X_train2 = train2[features]
y_train2 = train2[target]
X_val2 = val2[features]
y_val2 = val2[target]
X_test2 = test2[features]
y_test2 = test2[target]

train2.shape, val2.shape
# Out:
# ((1251, 20), (313, 20))

# %% [markdown]
# ### 1. Logistic Regression

# %%
# logisticregression, ordinalencoder

pipe_log_o = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서ㅁ가 상관없어서 괜찮다!
    LogisticRegression())

pipe_log_o.fit(X_train, y_train)
y_pred = pipe_log_o.predict(X_val)

print('훈련 정확도 :', pipe_log_o.score(X_train,y_train))
print('검증 정확도 :', pipe_log_o.score(X_val, y_val))
print('F1 score :', f1_score(y_val, y_pred))
print('AUC 점수 :', roc_auc_score(y_val, y_pred))
print('REPORT',classification_report(y_val, y_pred))
# Out:
# 훈련 정확도 : 0.833175355450237
# 검증 정확도 : 0.8106060606060606
# F1 score : 0.358974358974359
# AUC 점수 : 0.6057692307692307
# REPORT               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       208
#            1       0.64      0.25      0.36        56
#
#     accuracy                           0.81       264
#    macro avg       0.73      0.61      0.62       264
# weighted avg       0.79      0.81      0.78       264
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fig, ax = plt.subplots()
pcm = plot_confusion_matrix(pipe_log_o, X_val, y_val,
                            cmap=plt.cm.Blues,
                            ax=ax);
plt.title(f'Confusion matrix, n = {len(y_val)}', fontsize=15)
plt.show()
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
tp = 14
tn = 200
fp = 8
fn = 42
total = tp+tn+fp+fn

# %%
# 1로 예측할 확률
y_train.value_counts(normalize=True)[1]
# Out:
# 0.19146919431279621

# %% [markdown]
# ### 1-2. Logistic Regression(null->most_frequent)

# %%
# catboost, ordinalencoder

pipe_log_o2 = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서ㅁ가 상관없어서 괜찮다!
    SimpleImputer(strategy='most_frequent'),
    LogisticRegression())

pipe_log_o2.fit(X_train2, y_train2)
y_pred = pipe_log_o2.predict(X_val2)

print('훈련 정확도 :', pipe_log_o2.score(X_train2,y_train2))
print('검증 정확도 :', pipe_log_o2.score(X_val2, y_val2))
print('F1 score :', f1_score(y_val2, y_pred))
print('AUC 점수 :', roc_auc_score(y_val2, y_pred))
print('REPORT',classification_report(y_val2, y_pred))
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 훈련 정확도 : 0.8321342925659473
# 검증 정확도 : 0.7891373801916933
# F1 score : 0.36538461538461536
# AUC 점수 : 0.6048942741743881
# REPORT               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       244
#            1       0.54      0.28      0.37        69
#
#     accuracy                           0.79       313
#    macro avg       0.68      0.60      0.62       313
# weighted avg       0.76      0.79      0.76       313

# %% [markdown]
# ### 2. RandomForest

# %%
# randomforest_ordinal encoding

pipe_rf_o = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    RandomForestClassifier())

pipe_rf_o.fit(X_train, y_train)
y_pred = pipe_rf_o.predict(X_val)

print('훈련 정확도 :', pipe_rf_o.score(X_train,y_train))
print('검증 정확도 :', pipe_rf_o.score(X_val, y_val))
print('F1 score :', f1_score(y_val, y_pred))
print('AUC 점수 :', roc_auc_score(y_val, y_pred))
print('REPORT',classification_report(y_val,y_pred))
# Out:
# 훈련 정확도 : 1.0
# 검증 정확도 : 0.8863636363636364
# F1 score : 0.6341463414634146
# AUC 점수 : 0.7321428571428572
# REPORT               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       208
#            1       1.00      0.46      0.63        56
#
#     accuracy                           0.89       264
#    macro avg       0.94      0.73      0.78       264
# weighted avg       0.90      0.89      0.87       264

# %% [markdown]
# ### 2-2. RandomForest(null->mist_frequent)

# %%
# randomforest_ordinal encoding

pipe_rf_o2 = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    SimpleImputer(strategy='most_frequent'),
    RandomForestClassifier())

pipe_rf_o2.fit(X_train2, y_train2)
y_pred = pipe_rf_o2.predict(X_val2)

print('훈련 정확도 :', pipe_rf_o2.score(X_train2,y_train2))
print('검증 정확도 :', pipe_rf_o2.score(X_val2, y_val2))
print('F1 score :', f1_score(y_val2, y_pred))
print('AUC 점수 :', roc_auc_score(y_val2, y_pred))
print('REPORT',classification_report(y_val2,y_pred))
# Out:
# 훈련 정확도 : 1.0
# 검증 정확도 : 0.8626198083067093
# F1 score : 0.5981308411214953
# AUC 점수 : 0.7195889760038013
# REPORT               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       244
#            1       0.84      0.46      0.60        69
#
#     accuracy                           0.86       313
#    macro avg       0.85      0.72      0.76       313
# weighted avg       0.86      0.86      0.85       313

# %% [markdown]
# ### 2-3. RandomForest Hyperparameter Tuning

# %%
###### pipe라인 랜덤포레스트 모델의 파라미터튜닝
pipe = make_pipeline(
      OrdinalEncoder(),
      RandomForestClassifier(random_state=2))

# 튜닝할 하이퍼파라미터의 범위를 지정
parameters = {'randomforestclassifier__max_depth': range(1, 5, 2), 
              'randomforestclassifier__max_features': range(1, 5, 2), 
              'randomforestclassifier__min_samples_leaf' : range(1, 5, 2)}
    
# 최적의 hyper parameter를 찾기 위한 RandomizedSearchCV
rf_classifier = RandomizedSearchCV(pipe, 
                                    param_distributions=parameters, #  param_distributions : 사전/사전목록
                                    n_iter=10, # 정수, 기본값=10
                                    cv=5, # 교차검증생성기 또는 반복가능 default=None
                                    scoring='roc_auc', # 평가방법
                                    verbose=1) # 진행상황표시. 높을수록 더 많은 메세지표시.
rf_classifier.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(

# %%
# RandomSearchCV 결과 확인
print('Best Parameters :', rf_classifier.best_params_)
print('검증정확도 :', rf_classifier.best_score_)
# Out:
# Best Parameters : {'randomforestclassifier__min_samples_leaf': 3, 'randomforestclassifier__max_features': 1, 'randomforestclassifier__max_depth': 3}
# 검증정확도 : 0.7829650884744142

# %%
# randomforest_ordinal encoding

pipe_rf_o = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    
    RandomForestClassifier(random_state=2, min_samples_leaf=3, max_features=1, max_depth=3))

pipe_rf_o.fit(X_train, y_train)
y_pred = pipe_rf_o.predict(X_val)

print('훈련 정확도 :', pipe_rf_o.score(X_train,y_train))
print('검증 정확도 :', pipe_rf_o.score(X_val, y_val))
print('F1 score :', f1_score(y_val, y_pred))
print('AUC 점수 :', roc_auc_score(y_val, y_pred))
print('REPORT',classification_report(y_val,y_pred))
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# 훈련 정확도 : 0.7995310668229777
# 검증 정확도 : 0.7765151515151515
# F1 score : 0.4957264957264957
# AUC 점수 : 0.6820054945054944
# REPORT               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       208
#            1       0.48      0.52      0.50        56
#
#     accuracy                           0.78       264
#    macro avg       0.67      0.68      0.68       264
# weighted avg       0.78      0.78      0.78       264

# %% [markdown]
# ### 2-4. RandomForest Hyperparameter Tuning (null -> most_frequent)

# %%
###### pipe라인 랜덤포레스트 모델의 파라미터튜닝
pipe = make_pipeline(
      OrdinalEncoder(),
      SimpleImputer(strategy='most_frequent'),
      RandomForestClassifier(random_state=2))

# 튜닝할 하이퍼파라미터의 범위를 지정
parameters = {'randomforestclassifier__max_depth': range(1, 5, 2), 
              'randomforestclassifier__max_features': range(1, 5, 2), 
              'randomforestclassifier__min_samples_leaf' : range(1, 5, 2)}
    
# 최적의 hyper parameter를 찾기 위한 RandomizedSearchCV
rf_classifier = RandomizedSearchCV(pipe, 
                                    param_distributions=parameters, #  param_distributions : 사전/사전목록
                                    n_iter=10, # 정수, 기본값=10
                                    cv=5, # 교차검증생성기 또는 반복가능 default=None
                                    scoring='roc_auc', # 평가방법
                                    verbose=1) # 진행상황표시. 높을수록 더 많은 메세지표시.
rf_classifier.fit(X_train2, y_train2);
# Out:
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 8 candidates, totalling 40 fits

# %%
# RandomSearchCV 결과 확인
print('Best Parameters :', rf_classifier.best_params_)
print('검증정확도 :', rf_classifier.best_score_)
# Out:
# Best Parameters : {'randomforestclassifier__min_samples_leaf': 3, 'randomforestclassifier__max_features': 1, 'randomforestclassifier__max_depth': 3}
# 검증정확도 : 0.7670368231011342

# %%
# randomforest_ordinal encoding

pipe_rf_or = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    SimpleImputer(strategy='most_frequent'),    
    RandomForestClassifier(random_state=2, min_samples_leaf=3, max_features=1, max_depth=3))

pipe_rf_or.fit(X_train2, y_train2)
y_pred = pipe_rf_or.predict(X_val2)

print('훈련 정확도 :', pipe_rf_or.score(X_train2,y_train2))
print('검증 정확도 :', pipe_rf_or.score(X_val2, y_val2))
print('F1 score :', f1_score(y_val2, y_pred))
print('AUC 점수 :', roc_auc_score(y_val2, y_pred))
print('REPORT',classification_report(y_val2,y_pred))
# Out:
# 훈련 정확도 : 0.8097521982414069
# 검증 정확도 : 0.7795527156549521
# F1 score : 0.0
# AUC 점수 : 0.5
# REPORT               precision    recall  f1-score   support
#
#            0       0.78      1.00      0.88       244
#            1       0.00      0.00      0.00        69
#
#     accuracy                           0.78       313
#    macro avg       0.39      0.50      0.44       313
# weighted avg       0.61      0.78      0.68       313
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/hun/opt/anaconda3/envs/kerneljookjima/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 2-5. RandomForest Hyperparameter Tuning with SMOTE

# %%
# sampling_strategy=1.0

# 인코딩
encoder = OrdinalEncoder()
dataaa=encoder.fit_transform(data)

# 훈련/검증/테스트셋 나누기

train, test = train_test_split(dataaa, test_size=0.2, random_state=2)
train, val = train_test_split(train, test_size=0.2, random_state=2)
 
target = 'ProdTaken'
features = dataaa.columns.drop([target])

X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]
y_test = test[target]

# smote 적용
sm = SMOTE(random_state=2, sampling_strategy=1.0) # sampling_strategy = 'minority'
X_train, y_train = sm.fit_resample(X_train, y_train)

# Hyperparameter 적용
smote = RandomForestClassifier(random_state=2, min_samples_leaf=1, max_features=1, max_depth=1).fit(X_train,y_train)
smote_pred=smote.predict(X_val)


print('훈련 정확도 :', smote.score(X_train, y_train))
print('검증 정확도 :', smote.score(X_val, y_val))
print('f1 스코어 :',f1_score(y_val, smote_pred))
print('auc점수 : ', roc_auc_score(y_val, smote_pred))
print('Report \n',classification_report(y_val, smote_pred))
# Out:
# 훈련 정확도 : 0.7655334114888629
# 검증 정확도 : 0.7462121212121212
# f1 스코어 : 0.48854961832061067
# auc점수 :  0.6823489010989011
# Report
#                precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       208
#            1       0.43      0.57      0.49        56
#
#     accuracy                           0.75       264
#    macro avg       0.65      0.68      0.66       264
# weighted avg       0.78      0.75      0.76       264

# %%
ttt
# Out:
#         id   Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# 0        1  28.0  Company Invited         1             10.0  Small Business
# 1        2  34.0     Self Enquiry         3              NaN  Small Business
# 2        3  45.0  Company Invited         1              NaN        Salaried
# 3        4  29.0  Company Invited         1              7.0  Small Business
# 4        5  42.0     Self Enquiry         3              6.0        Salaried
# ...    ...   ...              ...       ...              ...             ...
# 1950  1951  28.0     Self Enquiry         1             10.0  Small Business
# 1951  1952  41.0     Self Enquiry         3              8.0        Salaried
# 1952  1953  38.0  Company Invited         3             28.0  Small Business
# 1953  1954  28.0     Self Enquiry         3             30.0  Small Business
# 1954  1955  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# 0       Male                       3                4.0          Basic
# 1     Female                       2                4.0         Deluxe
# 2       Male                       2                3.0         Deluxe
# 3       Male                       3                5.0          Basic
# 4       Male                       2                3.0         Deluxe
# ...      ...                     ...                ...            ...
# 1950    Male                       3                5.0          Basic
# 1951  Female                       3                3.0   Super Deluxe
# 1952  Female                       3                4.0          Basic
# 1953  Female                       3                5.0         Deluxe
# 1954    Male                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# 0                       3.0       Married            3.0         0
# 1                       4.0        Single            1.0         1
# 2                       4.0       Married            2.0         0
# 3                       4.0       Married            3.0         0
# 4                       3.0      Divorced            2.0         0
# ...                     ...           ...            ...       ...
# 1950                    3.0        Single            2.0         0
# 1951                    5.0      Divorced            1.0         0
# 1952                    3.0      Divorced            7.0         0
# 1953                    3.0       Married            3.0         0
# 1954                    3.0      Divorced            1.0         1
#
#       PitchSatisfactionScore  OwnCar  NumberOfChildrenVisiting Designation  \
# 0                          1       0                       1.0   Executive
# 1                          5       1                       0.0     Manager
# 2                          4       1                       0.0     Manager
# 3                          4       0                       1.0   Executive
# 4                          3       1                       0.0     Manager
# ...                      ...     ...                       ...         ...
# 1950                       1       1                       2.0   Executive
# 1951                       5       1                       1.0         AVP
# 1952                       2       1                       2.0   Executive
# 1953                       1       1                       2.0     Manager
# 1954                       3       0                       0.0   Executive
#
#       MonthlyIncome  ProdTaken
# 0           20384.0          0
# 1           19599.0          1
# 2               NaN          0
# 3           21274.0          1
# 4           19907.0          0
# ...             ...        ...
# 1950        20723.0          0
# 1951        31595.0          0
# 1952        21651.0          0
# 1953        22218.0          0
# 1954        17853.0          1
#
# [1955 rows x 20 columns]

# %% [markdown]
# ### 3. XGBoost

# %%
# from xgboost import XGBClassifier,XGBRegressor

pipe_xgb_o = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    XGBClassifier())

pipe_xgb_o.fit(X_train, y_train)
y_pred = pipe_xgb_o.predict(X_val)

print('훈련 정확도 :', pipe_xgb_o.score(X_train,y_train))
print('검증 정확도 :', pipe_xgb_o.score(X_val, y_val))
print('F1 score :', f1_score(y_val, y_pred))
print('AUC 점수 :', roc_auc_score(y_val, y_pred))
print('REPORT',classification_report(y_val, y_pred))
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# 훈련 정확도 : 1.0
# 검증 정확도 : 0.8484848484848485
# F1 score : 0.5555555555555557
# AUC 점수 : 0.7015796703296704
# REPORT               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       208
#            1       0.74      0.45      0.56        56
#
#     accuracy                           0.85       264
#    macro avg       0.80      0.70      0.73       264
# weighted avg       0.84      0.85      0.83       264

# %% [markdown]
# ### 3-1. XGBoost (null->most_frequent)

# %%
# from xgboost import XGBClassifier,XGBRegressor

pipe_xgb_o2 = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    SimpleImputer(strategy='most_frequent'),
    XGBClassifier())

pipe_xgb_o2.fit(X_train2, y_train2)
y_pred = pipe_xgb_o2.predict(X_val2)

print('훈련 정확도 :', pipe_xgb_o2.score(X_train2,y_train2))
print('검증 정확도 :', pipe_xgb_o2.score(X_val2, y_val2))
print('F1 score :', f1_score(y_val2, y_pred))
print('AUC 점수 :', roc_auc_score(y_val2, y_pred))
print('REPORT',classification_report(y_val2, y_pred))
# Out:
# 훈련 정확도 : 1.0
# 검증 정확도 : 0.8626198083067093
# F1 score : 0.638655462184874
# AUC 점수 : 0.7507721549061535
# REPORT               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92       244
#            1       0.76      0.55      0.64        69
#
#     accuracy                           0.86       313
#    macro avg       0.82      0.75      0.78       313
# weighted avg       0.86      0.86      0.85       313

# %%
data['ProdTaken'].value_counts(normalize=True)
# Out:
# 0    0.79624
# 1    0.20376
# Name: ProdTaken, dtype: float64

# %%
ratio0 = data['ProdTaken'].value_counts(normalize=True)[0]
ratio1 = data['ProdTaken'].value_counts(normalize=True)[1]
ratio = ratio1/ratio0
ratio
# Out:
# 0.2559025133282559

# %% [markdown]
# ### 4. CatBoost

# %%
# catboost, ordinalencoder

pipe_cat_o = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    CatBoostClassifier())

pipe_cat_o.fit(X_train, y_train)
y_pred = pipe_cat_o.predict(X_val)

print('훈련 정확도 :', pipe_cat_o.score(X_train,y_train))
print('검증 정확도 :', pipe_cat_o.score(X_val, y_val))
print('F1 score :', f1_score(y_val, y_pred))
print('AUC 점수 :', roc_auc_score(y_val, y_pred))
print('REPORT',classification_report(y_val, y_pred))
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
# Learning rate set to 0.012942
# 0:	learn: 0.6877364	total: 50.7ms	remaining: 50.6s
# 1:	learn: 0.6813340	total: 51.7ms	remaining: 25.8s
# 2:	learn: 0.6755792	total: 53.1ms	remaining: 17.7s
# 3:	learn: 0.6692904	total: 54.3ms	remaining: 13.5s
# 4:	learn: 0.6624200	total: 55.6ms	remaining: 11.1s
# 5:	learn: 0.6557981	total: 56.5ms	remaining: 9.37s
# 6:	learn: 0.6506050	total: 57.7ms	remaining: 8.19s
# 7:	learn: 0.6452265	total: 58.8ms	remaining: 7.29s
# 8:	learn: 0.6404615	total: 59.9ms	remaining: 6.6s
# 9:	learn: 0.6360073	total: 60.9ms	remaining: 6.03s
# 10:	learn: 0.6311917	total: 62ms	remaining: 5.57s
# 11:	learn: 0.6256624	total: 63ms	remaining: 5.18s
# 12:	learn: 0.6204027	total: 63.8ms	remaining: 4.84s
# 13:	learn: 0.6152119	total: 64.7ms	remaining: 4.56s
# 14:	learn: 0.6114048	total: 65.8ms	remaining: 4.32s
# 15:	learn: 0.6073202	total: 66.9ms	remaining: 4.12s
# 16:	learn: 0.6027553	total: 68.1ms	remaining: 3.94s
# 17:	learn: 0.5978153	total: 69.4ms	remaining: 3.78s
# 18:	learn: 0.5933080	total: 70.8ms	remaining: 3.66s
# 19:	learn: 0.5888721	total: 71.9ms	remaining: 3.52s
# 20:	learn: 0.5848921	total: 73ms	remaining: 3.4s
# 21:	learn: 0.5806660	total: 73.9ms	remaining: 3.29s
# 22:	learn: 0.5770658	total: 74.9ms	remaining: 3.18s
# 23:	learn: 0.5735805	total: 76ms	remaining: 3.09s
precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       208
#            1       0.80      0.50      0.62        56
#
#     accuracy                           0.87       264
#    macro avg       0.84      0.73      0.77       264
# weighted avg       0.86      0.87      0.86       264

# %% [markdown]
# ### 4. CatBoost (null->most_frequent)

# %%
# catboost, ordinalencoder

pipe_cat_o2 = make_pipeline(
    OrdinalEncoder(), # 범주형 자료를 모델링할 때는 원핫보다 오디널이 좋음! 중요한 노드가 상위에서 선택되어야하는데 원핫을하면 적용이 잘 안됨! 한가지 특성이 여러가지로 나눠지기 때문에! 그래서 노미널인코딩이라도 오디널을 사용함! 트리에서는 순서가 상관없어서 괜찮다!
    SimpleImputer(strategy='most_frequent'),
    CatBoostClassifier())

pipe_cat_o2.fit(X_train2, y_train2)
y_pred = pipe_cat_o2.predict(X_val2)

print('훈련 정확도 :', pipe_cat_o2.score(X_train2,y_train2))
print('검증 정확도 :', pipe_cat_o2.score(X_val2, y_val2))
print('F1 score :', f1_score(y_val2, y_pred))
print('AUC 점수 :', roc_auc_score(y_val2, y_pred))
print('REPORT',classification_report(y_val2, y_pred))
# Out:
# Learning rate set to 0.011336
# 0:	learn: 0.6854297	total: 1.04ms	remaining: 1.04s
# 1:	learn: 0.6783159	total: 1.81ms	remaining: 903ms
# 2:	learn: 0.6717506	total: 2.51ms	remaining: 834ms
# 3:	learn: 0.6663134	total: 2.96ms	remaining: 736ms
# 4:	learn: 0.6606514	total: 3.25ms	remaining: 647ms
# 5:	learn: 0.6555455	total: 3.96ms	remaining: 657ms
# 6:	learn: 0.6502760	total: 4.59ms	remaining: 651ms
# 7:	learn: 0.6438312	total: 5.26ms	remaining: 653ms
# 8:	learn: 0.6375194	total: 5.97ms	remaining: 658ms
# 9:	learn: 0.6307841	total: 6.67ms	remaining: 661ms
# 10:	learn: 0.6244982	total: 7.27ms	remaining: 654ms
# 11:	learn: 0.6185265	total: 7.96ms	remaining: 655ms
# 12:	learn: 0.6123586	total: 8.64ms	remaining: 656ms
# 13:	learn: 0.6067790	total: 9.37ms	remaining: 660ms
# 14:	learn: 0.6006446	total: 10.1ms	remaining: 666ms
# 15:	learn: 0.5960252	total: 10.8ms	remaining: 666ms
# 16:	learn: 0.5905824	total: 11.6ms	remaining: 672ms
# 17:	learn: 0.5861161	total: 12.3ms	remaining: 673ms
# 18:	learn: 0.5811800	total: 13.2ms	remaining: 679ms
# 19:	learn: 0.5766545	total: 13.8ms	remaining: 677ms
# 20:	learn: 0.5725356	total: 14.7ms	remaining: 685ms
# 21:	learn: 0.5677287	total: 15.5ms	remaining: 690ms
# 22:	learn: 0.5631920	total: 16.3ms	remaining: 691ms
# 23:	learn: 0.5581233	total: 17.3ms	remaining: 704ms
# 24:	learn: 0.5534664	total: 18ms	remaining: 704ms
# 25:	learn: 0.5508848	total: 18.4ms	remaining: 689ms
# 26:	learn: 0.5466006	total: 19ms	remaining: 686ms
# 27:	learn: 0.5421495	total: 19.7ms	remaining: 685ms
# 28:	learn: 0.5378275	total: 20.4ms	remaining: 685ms
# 29:	learn: 0.5353572	total: 20.8ms	remaining: 673ms
# 30:	learn: 0.5313211	total: 21.5ms	remaining: 672ms
# 967:	learn: 0.1474956	total: 759ms	remaining: 25.1ms
# 968:	learn: 0.1473214	total: 760ms	remaining: 24.3ms
# 969:	learn: 0.1471755	total: 761ms	remaining: 23.5ms
# 970:	learn: 0.1469919	total: 761ms	remaining: 22.7ms
# 971:	learn: 0.1468344	total: 762ms	remaining: 22ms
# 972:	learn: 0.1467074	total: 763ms	remaining: 21.2ms
# 973:	learn: 0.1466371	total: 763ms	remaining: 20.4ms
# 974:	learn: 0.1464757	total: 764ms	remaining: 19.6ms
# 975:	learn: 0.1463547	total: 765ms	remaining: 18.8ms
# 976:	learn: 0.1461750	total: 766ms	remaining: 18ms
# 977:	learn: 0.1459954	total: 767ms	remaining: 17.2ms
# 978:	learn: 0.1459574	total: 768ms	remaining: 16.5ms
# 979:	learn: 0.1457742	total: 768ms	remaining: 15.7ms
# 980:	learn: 0.1456670	total: 769ms	remaining: 14.9ms
# 981:	learn: 0.1455066	total: 770ms	remaining: 14.1ms
# 982:	learn: 0.1453726	total: 770ms	remaining: 13.3ms
# 983:	learn: 0.1451605	total: 771ms	remaining: 12.5ms
# 984:	learn: 0.1450267	total: 772ms	remaining: 11.8ms
# 985:	learn: 0.1448303	total: 773ms	remaining: 11ms
# 986:	learn: 0.1446947	total: 774ms	remaining: 10.2ms
# 987:	learn: 0.1446269	total: 774ms	remaining: 9.4ms
# 988:	learn: 0.1444390	total: 775ms	remaining: 8.62ms
# 989:	learn: 0.1443539	total: 776ms	remaining: 7.84ms
# 990:	learn: 0.1442238	total: 777ms	remaining: 7.05ms
# 991:	learn: 0.1441180	total: 777ms	remaining: 6.27ms
# 992:	learn: 0.1440023	total: 778ms	remaining: 5.48ms
# 993:	learn: 0.1438599	total: 779ms	remaining: 4.7ms
# 994:	learn: 0.1437327	total: 780ms	remaining: 3.92ms
# 995:	learn: 0.1436089	total: 780ms	remaining: 3.13ms
# 996:	learn: 0.1434994	total: 781ms	remaining: 2.35ms
# 997:	learn: 0.1433535	total: 782ms	remaining: 1.57ms
# 998:	learn: 0.1432854	total: 783ms	remaining: 783us
# 999:	learn: 0.1430356	total: 784ms	remaining: 0us
# 훈련 정확도 : 0.9680255795363709
# 검증 정확도 : 0.865814696485623
# F1 score : 0.6111111111111112
# AUC 점수 : 0.7268353528153955
# REPORT               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92       244
#            1       0.85      0.48      0.61        69
#
#     accuracy                           0.87       313
#    macro avg       0.86      0.73      0.77       313
# weighted avg       0.86      0.87      0.85       313

# %%
=?23
# Out:
#   Input In [72]
#     =?23
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 데이콘 대회 답안 제출 코드

# %%
test = pd.read_csv('data/test.csv')

# %%
# Predict the target using the testing data
y_pred_test = pipe_xgb_o2.predict(test)
y_pred_test = pd.Series(y_pred_test)
y_pred_test.value_counts()

# %%
# Create the DataFrame including predictions with "id" feature from the original data as index 
id = pd.Series(range(1,len(y_pred_test)+1))

submission = pd.concat([id, y_pred_test], axis=1)
submission.rename(columns={0:"id", 1:target}, inplace=True)

# Display the submission data information
print(submission.shape)
print(submission.value_counts(target))

# Export the dataset to a *csv* file.
submission.to_csv("data/submission.csv",index=False)
